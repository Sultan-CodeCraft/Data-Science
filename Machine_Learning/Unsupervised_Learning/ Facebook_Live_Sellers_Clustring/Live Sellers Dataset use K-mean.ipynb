# %% [markdown]
# # K-Means Clustering with Python
# Facebook Live sellers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Live.csv')
df
# Out:
#                               status_id status_type status_published  \
# 0      246675545449582_1649696485147474       video   4/22/2018 6:00
# 1      246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2      246675545449582_1648730588577397       video   4/21/2018 6:17
# 3      246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4      246675545449582_1645700502213739       photo   4/18/2018 3:22
# ...                                 ...         ...              ...
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
df.drop(['Column1', 'Column2', 'Column3', 'Column4'], axis=1, inplace=True)

# %%
df.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    7050.000000   7050.000000  7050.000000  7050.000000  7050.000000
# mean      230.117163    224.356028    40.022553   215.043121    12.728652
# std       462.625309    889.636820   131.599965   449.472357    39.972930
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        17.000000      0.000000     0.000000    17.000000     0.000000
# 50%        59.500000      4.000000     0.000000    58.000000     0.000000
# 75%       219.000000     23.000000     4.000000   184.750000     3.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys
# count  7050.000000  7050.000000  7050.000000  7050.000000
# mean      1.289362     0.696454     0.243688     0.113191
# std       8.719650     3.957183     1.597156     0.726812
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
len(df['status_id'].unique())
# Out:
# 6997

# %%
len(df['status_published'].unique())
# Out:
# 6913

# %%
len(df['status_type'].unique())
# Out:
# 4

# %%
df.drop(['status_id', 'status_published'], axis=1, inplace=True)

# %%
df
# Out:
#      status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0          video            529           512         262        432
# 1          photo            150             0           0        150
# 2          video            227           236          57        204
# 3          photo            111             0           0        111
# 4          photo            213             0           0        204
# ...          ...            ...           ...         ...        ...
# 7045       photo             89             0           0         89
# 7046       photo             16             0           0         14
# 7047       photo              2             0           0          1
# 7048       photo            351            12          22        349
# 7049       photo             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['status_type'] = le.fit_transform(df['status_type'])

# %%
df
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0               3            529           512         262        432
# 1               1            150             0           0        150
# 2               3            227           236          57        204
# 3               1            111             0           0        111
# 4               1            213             0           0        204
# ...           ...            ...           ...         ...        ...
# 7045            1             89             0           0         89
# 7046            1             16             0           0         14
# 7047            1              2             0           0          1
# 7048            1            351            12          22        349
# 7049            1             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %%
ms = MinMaxScaler()
df_scalar=pd.DataFrame(ms.fit_transform(df), columns=df.columns)
df_scalar
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0        1.000000       0.112314      0.024393    0.076519   0.091720
# 1        0.333333       0.031847      0.000000    0.000000   0.031847
# 2        1.000000       0.048195      0.011243    0.016647   0.043312
# 3        0.333333       0.023567      0.000000    0.000000   0.023567
# 4        0.333333       0.045223      0.000000    0.000000   0.043312
# ...           ...            ...           ...         ...        ...
# 7045     0.333333       0.018896      0.000000    0.000000   0.018896
# 7046     0.333333       0.003397      0.000000    0.000000   0.002972
# 7047     0.333333       0.000425      0.000000    0.000000   0.000212
# 7048     0.333333       0.074522      0.000572    0.006425   0.074098
# 7049     0.333333       0.003609      0.000000    0.000000   0.003609
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0      0.140030  0.010791   0.006369  0.019608         0.0
# ...

# %%
sse = []
k_rng = range(1,10)
for k in k_rng:
    km = KMeans(n_clusters=k,random_state=42)
    km.fit(df_scalar)
    sse.append(km.inertia_)
sse
# Out:
# [899.1609334281574,
#  240.06686397262814,
#  178.66340039279407,
#  130.3325194711556,
#  96.24993195940584,
#  89.04238066559026,
#  75.84694032787743,
#  68.59327636689252,
#  65.05938647393846]

# %%
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.plot(k_rng,sse)

# %%
km = KMeans(n_clusters=4)
km.fit(df_scalar)
# Out:
# KMeans(n_clusters=4)

# %%
labels = km.labels_
labels
# Out:
# array([3, 1, 3, ..., 1, 1, 1])

# %%
df_scalar['cluster']=labels
df_scalar
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0        1.000000       0.112314      0.024393    0.076519   0.091720
# 1        0.333333       0.031847      0.000000    0.000000   0.031847
# 2        1.000000       0.048195      0.011243    0.016647   0.043312
# 3        0.333333       0.023567      0.000000    0.000000   0.023567
# 4        0.333333       0.045223      0.000000    0.000000   0.043312
# ...           ...            ...           ...         ...        ...
# 7045     0.333333       0.018896      0.000000    0.000000   0.018896
# 7046     0.333333       0.003397      0.000000    0.000000   0.002972
# 7047     0.333333       0.000425      0.000000    0.000000   0.000212
# 7048     0.333333       0.074522      0.000572    0.006425   0.074098
# 7049     0.333333       0.003609      0.000000    0.000000   0.003609
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys  cluster
# ...

# %%
km.cluster_centers_
# Out:
# array([[1.00000000e+00, 3.15705918e-01, 1.07732325e-01, 1.32386524e-01,
#         2.76566484e-01, 2.31209319e-01, 7.70760276e-02, 5.15955574e-02,
#         3.20228594e-02, 4.06873075e-02],
#        [3.29212121e-01, 1.92465805e-02, 6.48839996e-04, 5.26196545e-04,
#         1.87796950e-02, 1.92721738e-03, 1.99520384e-03, 1.16116580e-03,
#         2.85204991e-03, 1.52492669e-03],
#        [4.07407407e-01, 3.78792862e-01, 3.04362177e-03, 4.15082310e-03,
#         3.77269889e-01, 5.86942032e-03, 1.08854093e-02, 1.47787353e-03,
#         1.02524670e-03, 2.10837023e-04],
#        [9.60743802e-01, 3.56672106e-02, 2.07887857e-02, 2.17440575e-02,
#         3.05505255e-02, 3.34006315e-02, 2.39609965e-03, 6.51418645e-03,
#         6.29557608e-03, 4.66542255e-03]])

# %%
#sns.pairplot(df_scalar, hue= 'cluster', palette='viridis')
#plt.show()

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(df_scalar, km.labels_)
print(f"Silhouette Score for 3 clusters: {silhouette_avg}")
# Out:
# Silhouette Score for 3 clusters: 0.9065825587273919

# %%
df1 = df_scalar[df_scalar.cluster == 0]
df2 = df_scalar[df_scalar.cluster == 1]
df3 = df_scalar[df_scalar.cluster == 2]
df4 = df_scalar[df_scalar.cluster == 3]

# Scatter plot for each cluster
plt.scatter(df1['num_reactions'], df1['num_comments'], color='green', label='Cluster 1')
plt.scatter(df2['num_reactions'], df2['num_comments'], color='red', label='Cluster 2')
plt.scatter(df3['num_reactions'], df3['num_comments'], color='black', label='Cluster 3')
plt.scatter(df4['num_reactions'], df4['num_comments'], color='blue', label='Cluster 4')

# Plotting the centroids
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], color='purple', marker='*', s=200, label='Centroids')

# Labels and legend
plt.xlabel('num_reactions')
plt.ylabel('num_comments')
plt.legend()
plt.title('K-means Clustering of Live Dataset')
plt.show()
